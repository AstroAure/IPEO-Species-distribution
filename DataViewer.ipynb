# %%
# %pip install numpy matplotlib pandas scikit-learn pytorch torchvision

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Environment variables
#
# Description of items: https://www.worldclim.org/data/bioclim.html

# %%
env_variables = pd.read_csv('env_variables_training.csv')
env_variables.head()

# %% [markdown]
# ## LandSat timeseries

# %%
landsat_timeseries = pd.read_csv('landsat_timeseries_training.csv')
landsat_timeseries.head()

# %%
bands = ['red', 'green', 'blue', 'nir']
year = np.arange(2008, 2018)
quarter = np.arange(1, 5)
