# %% [markdown]
# # Species distribution modeling with multimodal satellite and environmental data
#
# Welcome to this wonderfull main to discover the beauty of mother earth, enjoy your work and be happy :)

# %% [markdown]
# ## 1. Setup

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from tqdm import tqdm
import src.ModelUtils as mu
from src.MultimodalSDM import multimodal_SDM, load_model, save_model

# %%
assert torch.cuda.is_available(), "CUDA is not available. Please check your GPU setup."
# !nvidia-smi
# Out:
# Fri Dec 19 10:45:13 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:D8:00.0 Off |                  Off |
# | N/A   31C    P0              23W / 250W |      4MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
mu.root
# Out:
# '/home/agenin/IPEO-Species-distribution'

# %% [markdown]
# ## 2. Data loading

# %%
device = 'cpu'
batch_size = 8
# initialise data loaders
dl_train = mu.load_dataloader(batch_size=batch_size, split='train')
dl_val = mu.load_dataloader(batch_size=32, split='val')
dl_test = mu.load_dataloader(batch_size=32, split='test')

# %% [markdown]
# ## 3. Create model

# %%
model = multimodal_SDM() #load the model

# data = iter(dl_train).__next__()
# pred = model(data) #perform 1 forward pass

# %%
print(f"Size CNN_sat       : {mu.get_model_size(model.CNN_sat):.2f} MB")
print(f"Size MLP_env       : {mu.get_model_size(model.MLP_env)*1024:.2f} kB")
print(f"Size CNN_timeseries: {mu.get_model_size(model.CNN_timeseries)*1024:.2f} kB")
print(f"Size classifier    : {mu.get_model_size(model.classifier):.2f} MB")
# Out:
# Size CNN_sat       : 105.64 MB
# Size MLP_env       : 49.33 kB
# Size CNN_timeseries: 87.19 kB
# Size classifier    : 3.02 MB

# %% [markdown]
# ## 4. Model training

# %%
# define hyperparameters
start_epoch = 'latest'        # set to 0 to start from scratch again or to 'latest' to continue training from saved checkpoint
num_epochs = 101
learning_rate = 0.1
weight_decay = 0.001
freeze_sat_CNN = True

# load model
model, epoch = load_model(epoch=start_epoch)
# define loss function
criterion = torch.nn.BCELoss()
# setup optimiser
optim = mu.setup_optimiser(model, learning_rate=learning_rate, weight_decay=weight_decay)

# do epochs
while epoch < num_epochs:

    # optionally freeze satellite CNN weights
    for param in model.CNN_sat.backbone.parameters():
        param.requires_grad = not(freeze_sat_CNN)
    for param in model.CNN_sat.fpn.parameters():
        param.requires_grad = not(freeze_sat_CNN)

    # training
    model, loss_train = mu.train_epoch(dl_train, model, optim, criterion, device)

    # validation
    loss_val, auc_val = mu.validate_epoch(dl_val, model, criterion, device)

    # print stats
    print('[Ep. {}/{}] Loss train: {:.5f}, val: {:.5f}, AUC val: {:.5f}'.format(
        epoch+1, num_epochs,
        loss_train, loss_val, auc_val
    ))

    # save model
    epoch += 1
    if epoch % 10 == 0:
        save_model(model, epoch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 freeze_sat_CNN = True
#       8 # load model
# ----> 9 model, epoch = load_model(epoch=start_epoch)
#      10 # define loss function
#      11 criterion = torch.nn.BCELoss()
#
# File ~/IPEO-Species-distribution/src/MultimodalSDM.py:85, in load_model(epoch)
#      83 def load_model(epoch='latest'):
#      84   model = multimodal_SDM()
# ---> 85   modelStates = glob.glob(f'{root}/cnn_states/multimodal_SDM/*.pth')
#      86   if len(modelStates) and (epoch == 'latest' or epoch > 0):
#      87     modelStates = [int(m.replace(f'{root}/cnn_states/multimodal_SDM/','').replace('.pth', '')) for m in modelStates]
#
# NameError: name 'glob' is not defined

# %% [markdown]
# ## 5. Model evaluation

# %%
model = multimodal_SDM()
stateDict = torch.load(open(f'{mu.root}/cnn_states/multimodal_SDM/100.pth', 'rb'), map_location='cpu') # to change with the good name of the path
model.load_state_dict(stateDict)
model.to(device)
# Out:
# multimodal_SDM(
#   (MLP_env): Sequential(
#     (0): Linear(in_features=19, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=50, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=50, out_features=128, bias=True)
#     (7): ReLU()
#   )
#   (CNN_sat): Model(
#     (backbone): ResnetBackbone(
#       (resnet): ResNet(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
pred_test = []
for idx, sample in tqdm(enumerate(dl_test)):
    with torch.no_grad():
      # put data onto correct device and separate target from data
      sample = {key: value.to(device) for key, value in sample.items()}
      target = sample['species_labels'].float()
      data = {key: value for key, value in sample.items() if key != 'species_labels'}
      pred_batch = model(data)
      pred_test.append(pred_batch.cpu().numpy())
pred_test = np.concatenate(pred_test, axis=0)
# Out:
# 0it [00:00, ?it/s]
# 32it [01:55,  3.62s/it]

# %%
#auc
target = []
for idx, sample in tqdm(enumerate(dl_test)):
    # put data onto correct device and separate target from data
    sample = {key: value.to(device) for key, value in sample.items()}
    target_batch = sample['species_labels'].float()
    target.append(target_batch.cpu().numpy())
target = np.concatenate(target, axis=0)

fpr=[0 for _ in range(342)]
tpr=[0 for _ in range(342)]
roc_auc= [0 for _ in range(342)]
for i in range (342):
    fpr[i], tpr[i], _ = roc_curve(target[:, i], pred_test[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
roc_auc = np.array(roc_auc)
# Out:
# 32it [00:00, 37.74it/s]

# %%
from matplotlib.ticker import PercentFormatter

roc_auc_sort = np.array(roc_auc, copy=True)
roc_auc_sort.sort()

fig, ax = plt.subplots(figsize=(10,4))
ax.bar(np.arange(len(roc_auc_sort)), roc_auc_sort[::-1], color='orange', width=1.0)
ax.axhline(y=np.mean(roc_auc_sort), color='red', linestyle='--', label='Mean AUC')
ax.axhline(y=0.5, color='blue', linestyle='--', label='Random Guessing')
ax.set_xlim(-10, len(roc_auc_sort)+10)
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
ax.set_xlabel("Species index (sorted by AUC)")
ax.set_ylabel("AUC")
ax.legend()
plt.show()
# ax.boxplot(roc_auc)
print("Mean AUC:", np.mean(roc_auc_sort))
# Out:
# Mean AUC: 0.8281806785646445

# %%
# Species occurence counts
species_labels = np.concatenate([s['species_labels'] for s in dl_train], axis=0)
species_counts = species_labels.sum(axis=0)

# %%
# Bins for species counts vs AUC
log_bin = np.logspace(np.log10(species_counts.min()), np.log10(species_counts.max()), num=10)
bin_indices = np.digitize(species_counts, log_bin)
bin_auc_mean = [roc_auc[bin_indices == i].mean() for i in range(1, len(log_bin))]
bin_auc_std = [roc_auc[bin_indices == i].std() for i in range(1, len(log_bin))]

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.scatter(species_counts, roc_auc, color='orange', s=10, label='Species AUC')
ax.errorbar(
    x=[(log_bin[i] + log_bin[i-1]) / 2 for i in range(1, len(log_bin))],
    y=bin_auc_mean,
    yerr=bin_auc_std,
    fmt='o-',
    color='r',
    capsize=5,
    label='Binned mean AUC ± std'
)
ax.set_xscale('log')
ax.set_xlabel("Occurrences of species in training set")
ax.set_ylabel("Species AUC")
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
ax.set_ylim(0.5,1.05)
ax.legend()
plt.show()

# %%
# TODO : Result image visualization

# %%
#F1 score with a treshold of 0.5
# we can select the best treshold for each species according to the F1 score
from sklearn.metrics import f1_score
f1_scores = [0 for _ in range(342)]
for i in range(342): # for each species
    f1 = f1_score(target[:, i].cpu(), (pred_test[:, i].detach().numpy().cpu() > 0.5).astype(int)) #0.5 treshold
    f1_scores[i] = f1
print(f1_scores)
plt.bar(range(len(f1_scores)), f1_scores)

# micro f1 score 
'micro:Calculate metrics globally by counting the total true positives, false negatives and false positives. (from sklearn doc + botella 2023 +van tiel paper)'
f1_micro = f1_score(target.cpu(), (pred_test.detach().numpy().cpu() > 0.5).astype(int), average='micro')
print(f1_micro)

# macro f1 score
'macro:Calculate metrics for each label, and find their unweighted mean. This does not take label imbalance into account.'
f1_macro = f1_score(target.cpu(), (pred_test.detach().numpy().cpu() > 0.5).astype(int), average='macro')
print(f1_macro)
